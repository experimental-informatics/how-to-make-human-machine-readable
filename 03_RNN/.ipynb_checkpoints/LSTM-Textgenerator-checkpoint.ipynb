# %% [markdown]
# this notebook is the base of the code for the artwork [EIN STÜCK „LYRIK“: AUTOPOESIE APPARATUS FÜR ANTIKAPITALISTISCHE WERBEMITTEL](https://exmediawiki.khm.de/exmediawiki/images/3/35/KI-Plakat.pdf) from our former student [Verena Lercher](http://www.verenalercher.com/)
#
# ---

# %% [markdown]
# # Text generation mit LSTM
#
#
# ## Implementierung der LSTM-Texterzeugung für Zeichen
# ![](./data/character-level_neural_language_model.png)

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %% [markdown]
# ## Daten vorbereiten
#
# laden und konvertieren in 'lowercase':

# %%
import keras
import numpy as np

#eigenes textfile (in UTF-8)
text = open("./data/KeinerWeissMehr.txt").read().lower()
print('Länge des Textkorpus:', len(text))
# Out:
# Länge des Textkorpus: 462081

# %% [markdown]
# umschreiben...:
# 1. sequenzen mit der länge `maxlen` extrahieren
# 2. mit `one-hot-encoding` in numpy-array `x` umwandeln
# 3. numpy-array mit der `Shape(sequences, maxlen, unique_characters)` speichern
# 4. numpy-array `y` für zielwerte vorbereiten

# %%
# Exraktion von 60-Zeichen-Sequenzen
maxlen = 60

# sampling einer neuen sequenz nach jeweils 3 zeichen
step = 3

# speichern der extrahierten sequenzen
sentences = []

# speichern der zielwerte (der vorhergesagten zeichen)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Anzahl der Sequenzen:', len(sentences))

# Liste der unterschiedlichen Zeichen erstellen
chars = sorted(list(set(text)))
print('Anzahl der in diesem Text verwendeten Zeichen:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# one-hot Kodierung in binäre Arrays
print('Vektorisierung...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Anzahl der Sequenzen: 154007
# Anzahl der in diesem Text verwendeten Zeichen: 53
# Vektorisierung...

# %% [markdown]
# ## KNN erzeugen
#
# 1. ein einzelner `LSTM` layer
# 2. ein `Dense` Klassifizierer
# 3. Berechnung der softmax-Funktion aller möglichen Zeichen

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Da die Zielwerte one-hot encoded wurden,
# benutzen wir `categorical_crossentropy` als Verlustfunktion um das Netz zu trainieren:

# %%
from tensorflow.keras import optimizers
optimizer = optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /home/whoami/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %% [markdown]
# ## Trainieren des Sprachmodells und Sampling
#
# Mit trainierten Modell und einem kleinen Anfangstext neue Texte erzeugen...:
#
# 1. Wahrscheinlichkeitsverteilung (anhand bereits erzeugten Textes) für das nächste Zeichen erzeugen
# 2. Neugewichtung für eine bestimmte Temperatur durchführen
# 3. das nächste Zeichen erzeugen
# 4. das neue Zeichen am Ende des Textes hizufügen
#
# Code zur Neugewichtung und zum Abrufen eines Zeichenindex (Sampling-Funktion):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally - Das Modell trainieren und Text erzeugen
#
# nach jeder Epoche verschieden Temperaturen verwenden
#
# *...zum beobachten wie sich der erzeugte Text entwickelt und wie sich die verschiedenen Temperaturen der Sampling-Stratgie auswirken:*

# %%
import random
import sys

# Das Modell 60 Epochen lang trainieren
for epoch in range(1, 60):
    print('epoch', epoch)
    # Anpassung des Modells für einen Trainingsdurchlauf
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Zufällige Auswahl eines Anfangstexts
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Erzeuge Text mit dem Anfangswert: "' + generated_text + '"')
    
    # ausprobieren verschiedener Temperaturen
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ Temperatur:', temperature)
        sys.stdout.write(generated_text)

        # vom Anfangstext ausgehend 400 Zeichen erzeugen
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                # one-hot-codierung der schon erzeugten zeichen
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            # sampling des nächsten Zeichens
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1204/1204 [==============================] - 122s 100ms/step - loss: 1.8804
# --- Erzeuge Text mit dem Anfangswert: ", hinter der das grüngelände einsetzte an der
# universität, h"
# ------ Temperatur: 0.2
# , hinter der das grüngelände einsetzte an der
# universität, hatten sich das war es das sich einmal waren, das sich einmal eine fraufen, die es sich das sich das sich auf dem schwaren in der schwerrenden hausen standen sich das er sich das sich das sich das haufen sich das strecken waren sich das sich alle sich das er sich einem allegen waren sich einmal ein auf dem stadt das einem schlagen, die es sich auf dem schwaren waren, daß er sich das auf der schware
# ------ Temperatur: 0.5
# sich auf dem schwaren waren, daß er sich das auf der schwaren das war es sich dann das schwie schwer vor ihnen zugenenden kleinen alles meine vorgegen.
# das war es er hattenn stadt schon eingestrecken geschäfen, der stadt sich den pelsen,
# waren ein straße, es sich das strecken waren follissen,
# das er sich immer sich nicht er stall, die er dachen standen, das waren es war nicht er das einer zugengekläuffen. einem kleine geschlegrenden
# wurden einfachen, das n
# ------ Temperatur: 1.0
# läuffen. einem kleine geschlegrenden
# wurden einfachen, das nun
# damußen
# dem sich alse login, dasachten. die jagen und er mit wieder auf deß keiter gutstese ßinz mab ja veruntschlagen.
# aber nicht abere zinnmer war er und zu er, ist auf der bistfälliger andereh und war
# ein vor berädkig kind
# er mit den, weiter, sprecke er naß das weiter auser. hauten,
# tattend, drocken in der in dem schwehz, konntere kahnen und
# weiter schlauhen, kachig
# ston, es gauchot. var,
# ei
# ------ Temperatur: 1.2
# ahnen und
# weiter schlauhen, kachig
# ston, es gauchot. var,
# einmalko nicht es raden. dinkfrespfindsingseit mir kam nurmainze.
# daß einmaloen
# schwigigen.
# und derwe fagen, der sich doß und dranicün allerhalien bleibesen., gegrxadfanternichtaan in einecgechefkfolbe steltes sich in sif zeite lagt vornachen recdechichte, unt, min
# ein mirpiecke verzuginven faufscheibäschwahen
# und so, es
# mit einfauberdröjenes, sich
# ohnotwes kössen,
# daweißer ährengeschobiherigkblüben
# epoch 2
# 1204/1204 [==============================] - 124s 103ms/step - loss: 1.5356
# --- Erzeuge Text mit dem Anfangswert: "schonung und muß andauernd zuckerwasser
# zu mir nehmen. du pf"
# ------ Temperatur: 0.2
# schonung und muß andauernd zuckerwasser
# zu mir nehmen. du pföcklich auf dem stallen gestellt, die er sich darin stand auf den starre er sich darin an der stallen auf dem aben stand und die stadt auf dem ausgestilbten halten alle er nicht eine gerald auf dem andere er stant, die er sich darin stand einfach daran auf der stallen und wieder die stallen stand und die straße darin an den andere stand und der andere er sich darin an der stallen und wirken an den
# ------ Temperatur: 0.5
# nd der andere er sich darin an der stallen und wirken an den andere ergeppfett und zu bewegten gerald und sie hatte sie er so andere mußte und der bett mit dem er sich an sich arstall so aber zu schmanken, nicht mehr in einem licht ihr schon zusammen nicht mit dem arte immer einfach aber wie er sich mit ihr mußte er vor dem kar das sie immer war sie er daran gekart, alle dir frau. die er schon gestellten flache auf der aber standen darin und nicht daran zu
# ------ Temperatur: 1.0
# tellten flache auf der aber standen darin und nicht daran zusammen, rüschten is um sein, sehr sähalre unde ausvernsten in weiche erpfeckt purzig
# und, sinder russen, obwähre, nichts gerederrul, wird auffall, bit auf. die stull. wenn man klein geblieben wieder ausgehaltersogendgissensten vols er im ikt wenig, gerist daries, gläng und vorherz. aber konnte schiefig, zu sprabt einge purgigen lacken triechen önn, die fotter mit geirht mit direnen hauttaide darin
# ------ Temperatur: 1.2
# echen önn, die fotter mit geirht mit direnen hauttaide darinebfändere, wirden irt pfößen mit dhrosselra. es nun weiter
# aufwinm in seinem rotlich er wieder sich mehr sein fande, etwas mußigke roßel ging gesickt eugeozmmit igand dachäußm gilfegungesverdvors
# mit einem kitre, nicht eben machtirter als
# ihn
# allgeräuschentägle, vieren unten oöngetöllich
# und unaner alle enöltere du geraugenal, mal irn nichts, die zimmer abgebür, verbörnig on still, war kalsen volh
# epoch 3
# 1204/1204 [==============================] - 118s 98ms/step - loss: 1.4380
# --- Erzeuge Text mit dem Anfangswert: "eutung ein stück leerer himmel, blasses licht vormittags mit"
# ------ Temperatur: 0.2
# eutung ein stück leerer himmel, blasses licht vormittags mit den straßen darin das anderen gesehen, die anderen stelle die stadt, wie er die straßen sich das anderen gesicht das ausgehen, die sich stelle eine stand die straßen die frau, die sich war das anderen stelle und den straßen war, die sich anderen stelle die straßen andere straßen anderen stelle die straßen, die sich das kann sie sich das eine stand, die sich das ausgestellt, der stand das anderen
# ------ Temperatur: 0.5
# eine stand, die sich das ausgestellt, der stand das anderen winzelden von den hausen, die sich war die stelle sich andren und da war nicht das schien sich das allein das einmal da war nicht da ihr das ein ersten, gesicht, die sitzen und eine geworden war ein beim etwas anderen stimmen, die sich weiter andren können, die sich eine stand hinein, worder sich hatte ein toten, das kind länger anderes zu sehren, die für sie sich ein waren sich nicht das kind sic
# ------ Temperatur: 1.0
# u sehren, die für sie sich ein waren sich nicht das kind sich war verwohnlich muck, sich androns nimmel an den autlich weg.
# dann brauchte hinter ihr darüber in leinendig, die ruhe erwillt, an einer brand immer noch, wie er reiner, aber näh glau undlionnen spitteren. die ser. wie shazb auch destetzt, die einzigend zu stunzen, von der stchen
# von wildern
# aufhörlend, der kind, so stelle einänderen stelle die schrändlich weit reit, sie mehr, voreingestumpf gewa
# ------ Temperatur: 1.2
# lle die schrändlich weit reit, sie mehr, voreingestumpf gewah für in können zuwa und anddnicht wie doch natt, sich zuwehe, und die g wie da. dafbe nimmen, weiterdeuthiem, alles,
# ihm, jetzt
# wollähaltung, die rehand, so die winzungen
# an dem raunlichten, hier einmal gewcnde mainen. artsäudih. demu
# ausdeänähluls, morent,
# ein wenig jetzt veränderigen
# blie dem kleid, fent, golins,
# ohne wär, anderese deawkauken, aufede brünsten anfungen, ist es unsinänigung, und
# epoch 4
# 1204/1204 [==============================] - 119s 99ms/step - loss: 1.3925
# --- Erzeuge Text mit dem Anfangswert: "n welcher stelle,
# alles voll von leuten, immer, überall, als"
# ------ Temperatur: 0.2
# n welcher stelle,
# alles voll von leuten, immer, überall, als sie sich das er sich das beschäftigt hatte, das sich sich zu sehen war, das sie sich so war das man schon er nicht mehr gesicht und das sich das das so war das sich auf der augenblick war das sich schon das nicht mehr daran sein war das sie erst nur das auch das man sich das gesicht das er sich auf der augenblick und das stand auf der stadt war es das sie sich seinen sich das sich schon er nicht
# ------ Temperatur: 0.5
# adt war es das sie sich seinen sich das sich schon er nicht nur auch nicht ihre gesicht er so war nur das war es ist denn auf sie bewegte sich das war und zu sehen hatte, sie beweiten mit den zu sehen auf der stielige ausgesicht, ihm das war es daran schon wollte von ihm klar in der dachte sich darauf das nach das schon aus den schon war nicht mehr noch nicht mehr das noch nicht mehr nur gerade auf die leute sich bewegen, das sie schon und sich das angesan
# ------ Temperatur: 1.0
# f die leute sich bewegen, das sie schon und sich das angesand beune, die sich war moterzugehalten, den ich getalle. das wetter kommen menden hatte, so lag durchintere
# der zimmer noch vor. das jetzt darangenadim oder was schon seleschüngen, wenn er schon erst das ein gesicht war sie stimmee beschäftigten ihre übrugu, sehr barbeid zetterlos wenn
# nutfücht. man kam ozlive ja musik, die gutarfel benalkt, vorauf
# gesicht heraus, bis detlo sphüft gesicht, wie er s
# ------ Temperatur: 1.2
# t, vorauf
# gesicht heraus, bis detlo sphüft gesicht, wie er so laut, was, an, ist das trocken und ganz hältne auf
# der lchingenauberdang sie war sich sag sie nicht. under einrigeft, mutie, irg, der sßes abzuiden alt, an. von ihm, ihre strecken alt lakrückgephrtenektsotztren
# tompieren und nichts holte, und erzährte fas . darin der serzmüchungenm
# noch nach
# vier
# haar. vord schoch ar sein, nicht sehen herustt, eine lassen hätteren is los langen zu für sich, oder
# epoch 5
# 1204/1204 [==============================] - 121s 100ms/step - loss: 1.3564
# --- Erzeuge Text mit dem Anfangswert: "was man so bad nannte, ein toilettenbecken,
# ein spülstein, e"
# ------ Temperatur: 0.2
# was man so bad nannte, ein toilettenbecken,
# ein spülstein, ein genauern darauf das dann allein darauf dem straße auf dem ausgelegten waren, war es sich auf dem ausgenollen war, das war es sich aus der straße stand auf dem augenblick und sich auf dem auf dem kind, das sich in dem augenblick auf dem augenblick und sich auf dem anderen straßen stand und das aus der straße auf dem straße stand und dann an der straße schon auf dem ausgestanden war, das war es s
# ------ Temperatur: 0.5
# n an der straße schon auf dem ausgestanden war, das war es sich mehr aus der erledenstimmeresteil das gehalten sein, das sie kann sich das und das haben sitzend allein aus das war alles sie an der straße dir schon wie ein wagen der gerald das war es ihm sah, wie ein kleinen anfingen kleinen einzelnen ausgekommen in der stadt und sehr zu leute, satzändern stand zu halten sie sich vorgestrichenen klarer sich beim unsin einer wagen auf dem schon längert zu sp
# ------ Temperatur: 1.0
# arer sich beim unsin einer wagen auf dem schon längert zu spreckten und aber nicht in der, die tagen, das satzzedifrenhatten schlieven zu abend, abgimmen stame, so anschimmermiken.
# da ist ergleich. so trotzß sein, das kann nicht dann, ja, eince, dausiknnliche wunstmaldplatten
# ihnen verumsu, hat dichten mal.
# die bilder, irgendwie hin ihr verschimnest etwas, von dem verstanden alles ausseit. doch, sellem umeinisserentkäufl, entlang. im wohnung glaubt in der
# ------ Temperatur: 1.2
# ellem umeinisserentkäufl, entlang. im wohnung glaubt in der etztelldeänc, giser kurz in kleine
# paigige
# wimpse, vertrack stumpels red, für sie einge verkleidekliort bestimmtend,
# sagzem
# spazier, und erweglen. es auf einmustund um, wie zeitrchvinlen
# zusehen hatte. durch buntsam mderstimmertahrieros sein. in knichn als belmenbig
# damit, jedesuchlone aufs anderes
# und war es und sehr einklepfe, für zu könnend, die
# wollanis, damit sse durchsichtaus ba. sie hat das
# epoch 6
# 1204/1204 [==============================] - 123s 103ms/step - loss: 1.3284
# --- Erzeuge Text mit dem Anfangswert: "es gar
# nicht mehr ausreichen konnte, was sie miteinander mac"
# ------ Temperatur: 0.2
# es gar
# nicht mehr ausreichen konnte, was sie miteinander machen war, wenn er sich noch einmal das war das war es nicht mehr an den schaufen schieben war, das fahren und sehr das zimmer war es nicht mehr an den beinen waren das hängt es nicht an den kind, das sich aus dem kind ausgeschnieden war, das sich nicht mehr ausgestreckt hatten war, das sich das hatte er sich an der stadt, das war es ganz anderes an den schaufenster schlagen schneller auf dem beinen
# ------ Temperatur: 0.5
# nderes an den schaufenster schlagen schneller auf dem beinen hatten mit ihr hatte er wohl man sich verstand, das war es war das so eine schneller entgerichtet, das sich an einem zimmer tat betren, daß er die er sich von ihm nicht angenommen, daß es er sich aus den andere an den bluten aus dem anderen waren, noch einmal zu sehen war, wenn er sich machen. das hatte er noch ein bogen, hermut ein andern war, wenn er sich immer weiter auf den standen mit ihr vo
# ------ Temperatur: 1.0
# rn war, wenn er sich immer weiter auf den standen mit ihr von dem black, kannst umändern war nur irgendwo und kah
# steilen al, außerhalbe schaltfallen fenfern. es ga. ein käumen zu sehen runden, die nun soll, so, sagenn anderss, in dem schlazen nähnahtige
# fiese in ihrer büsen, unsinnone, gafzen, rückt ssehen sich zu spät auf den platzs wie das ja nun das bluten zugingen fohnen war sehr war, man wenig erzinnte. in sein, vagen sich ein andern dieser gesich fü
# ------ Temperatur: 1.2
# ig erzinnte. in sein, vagen sich ein andern dieser gesich für den toschen? mehr gängs, mach unsinr
# hall
# bleiben einl gekommen außer dek angeromgen, andern und spitzeld hinter ihm müden, ihn zunichtt
# wärmen übem zahen, antschdplch hütle, sehr es. um die fahr.
# mit sich ganz zu
# schzimmer, ein jahen und unter
# der kazuferm er sdeil da belken war. diese wenigytikan, ach nüchfinger,
# mit einem einkam
# schnoll mit den unsichem weichs, in endlich darat war, aber dann
# epoch 7
# 1204/1204 [==============================] - 133s 111ms/step - loss: 1.3060
# --- Erzeuge Text mit dem Anfangswert: "daraus herausgerutscht, langsam,
# immer schneller, weiter weg"
# ------ Temperatur: 0.2
# daraus herausgerutscht, langsam,
# immer schneller, weiter weg das ausgestrecht hatte, die schlaffte und die straße vorbeigenauseten, die sie sich dabei ihm hinter ihm war aber die schlaffte war in dem aus der straße vor ihm auf dem ausgeschlafft hatte, daß es nicht mehr so war, daß es nicht mehr auf dem augenblick auf die straße geschlossen hatte ein schlafftlog auf die schlafft zu sehen war, die schlaffte und die er sich da war, daß sie sich das schlafft u
# ------ Temperatur: 0.5
# chlaffte und die er sich da war, daß sie sich das schlafft und sie stand in der er hätte sie das schlafft das aber mit einem mit einem vors geregten aus der straße vor ihm war immer schließlich herum schließlich schloß mit dem wie ein geschlußte war von ihm auf die herufter einfach in der straße war, das hier sich im platte es schon gegenüber hochte, die schlafft von ihm waren in den schlafft oder auf dem schlafftte vor ihm auf die er noch mit einem mußte
# ------ Temperatur: 1.0
#  auf dem schlafftte vor ihm auf die er noch mit einem mußte etwas wurde wieler flben war schlafflichtlos waren, im abstell, ja auch zeigte er eine schlafend was sie sich worfte diese, die kind ihn ja er gedacken, er fhaft, frau, das gig malchem alle in einem leere bewean, war unter d. weng vorlungstauchen darauf, hier er mit erklägilung wegder, die hitter, vergeben, wo friebisch es nichts mehr hintelns, antuntso sehr in der wash hinein kannte, so daß er sc
# ------ Temperatur: 1.2
# telns, antuntso sehr in der wash hinein kannte, so daß er schihr und b, dann mal un, hinter gegen immer mals, wie der mehr rußte aufgestecht
# wunden, und ein rasch schrafe beid. man  in jeder die
# er emplaten, die an kümmel kalu
# verrattotscher vor ihr wegweg, muft
# würde verschlafft, anderen, kommraurgegangen hittauf. die schloßfsteplägliche, neu überdrausen mit dem lief zufüch
# noch nicht mehr ließ wie ich velliebe es hechritige feststelle
# haus mehr rutäl sic
# epoch 8
# 1204/1204 [==============================] - 122s 101ms/step - loss: 1.2954
# --- Erzeuge Text mit dem Anfangswert: "so wie die bunten, in matten
# pastellfarben gehaltenen aufnah"
# ------ Temperatur: 0.2
# so wie die bunten, in matten
# pastellfarben gehaltenen aufnahren, die sich vornachten, die sie das kleine er sich das gelassen, die sie das eine stadt, der stand der straße schaufender schrig der winzer der straße darin, die sich der stadt, die schon das gerald der straße gestenden beiden bestimmten körper in der stadt, die sich das gelegt, die schaufender geworden, sie war das mit dem schaufendel der anderen stadt, die beschäftigt,
# die schnell, die sich da
# ------ Temperatur: 0.5
# der anderen stadt, die beschäftigt,
# die schnell, die sich darüber, ein gekrocht, die leute gerussenden beinen stelle das schließlich ein schlafen sich wonner den köpfe, seinen gesicht, in dem rocke einfach schon so stimmt, einem schracken gerichten gesacht, der man er gerald lag, dem er sich zu sehen war, wie ein schon aber sich eine zimmer immer so angestanden, die gerald der stelle noch eine kind, ein der dann der wohnung der einzelnen schon das nicht so
# ------ Temperatur: 1.0
# d, ein der dann der wohnung der einzelnen schon das nicht so nieeo, getrente, könne es sich
# schnall. er ausschickt,
# dachte, steh er sie, gsomberte. er wieder lang, vderen niedred. so nachamebartig,
# auch bliebe, den istrokommen rig da kanntet. freiemutis, dieses al ssen. ohne sich zumerrcht, als schlig iger, anzunaßmer odem beiden geleintelle, irgend mit herum
# blichung noch einmal, und nichts ein augen, welche, wooömömöllst der triltierte körper war, sie wu
# ------ Temperatur: 1.2
# ugen, welche, wooömömöllst der triltierte körper war, sie wurde er und sehr daß
# du längsiger, wirklich spall doch geht in englierten genaus, körper grund sehen gerecht konnten. er vorgenamm war, arten musik. dort ancighehen. raänte
# sich darin, gerecheg bedle schotte und alle raum, weg, um die stchischen
# und mit ihm sonst
# hältn
# mitschauschwahre wäre.
# von wieder so wie das dein dabei yortcht und unten unhangen also immer da
# unt, den anrise im paßte. das zuda
# epoch 9
# 1204/1204 [==============================] - 141s 117ms/step - loss: 1.2833
# --- Erzeuge Text mit dem Anfangswert: "augen schließen, und dann nach einigen augenblicken
# ohne noc"
# ------ Temperatur: 0.2
# augen schließen, und dann nach einigen augenblicken
# ohne noch einmal das zurückgehen war ausgekommen war, daß er sich das zu sehen war, sie das weiter die straße bewegungen war, daß er sich das gerald genau das zugesteckt hatte, wie er sich ausgestreckt hatte, was er das gerald ausgestreckt war auszihhen war, das mitten den bestimmte sich ausgestreckt hatte, wie er sich sich das durch die er sich das zimmer war es sich das gerald wieder einmal das ein stad
# ------ Temperatur: 0.5
# das zimmer war es sich das gerald wieder einmal das ein stadt gestengt war, wie es das ihm vorsternter ihn auch nichts andere weggestopft hatte er die an die haustrotz gestellt hatte, das zurückgestellten tür einfach ausgehen einfach die hockzusammen hatte er war es das mitten in der stadt gegenüber ihr das ein freundlich sitzend, eine ausgestreckt, der er hinter den belderstrecken, wo er sich die stadt, das ein guten hellen wurden ein genäuscht hinter den
# ------ Temperatur: 1.0
#  stadt, das ein guten hellen wurden ein genäuscht hinter den einem wenigen aus ihr an sich der genäusch. figlöße
# unten schulb
# nichtlängen, in alloden viert
# war hei, nicht anders saugendeinandersehen für ich her neu verstzigen
# beispenzen änder, ein zu fläse so bewegung
# an macker täge, und außerdimarübe
# ins kommtig,
# warmen eine licht übersiente flach. iber und deinen film, die bewegung, lef. und auch er das zimmer das bilder, bute und die tropfen zu vergenau
# ------ Temperatur: 1.2
# h er das zimmer das bilder, bute und die tropfen zu vergenau
# zupflprün, ihr verbillt worden, noch einmllift, genau kum häusas artringen war, rücksacht. der fanbenhause,
# ine, alle verhreise, richte sie
# denken- umtrilate und
# war nein von ihrseita
# viel und darüber sie wah sie die st. ader.
# prüfthaarsätziges hmkluverwegen. wenn er sich den
# ruhigen
# lebentei, buch, erstausen, die ringlitbar betomm, eines alss otwack weggehallen wärmte. s
# ebennen densellchenfälli
# epoch 10
# 1204/1204 [==============================] - 135s 112ms/step - loss: 1.2708
# --- Erzeuge Text mit dem Anfangswert: " rainer kein grund oder sie, seine frau,
# nicht zurückzufahre"
# ------ Temperatur: 0.2
#  rainer kein grund oder sie, seine frau,
# nicht zurückzufahren, das genaugenammen, die sich das das doch nicht sehr so, daß er sich das doch an der er sich das genaugenammen, der sich auch das gesichter, die sich auch nicht so, das genaugenammen, die sich das doch nicht so so aus dem anderen beinen aus der stadt, der anderen stadt wieder an der straße sehen würde. das kind wieder die stadt, der sich das doch nicht so, daß er sich das doch das doch nicht meh
# ------ Temperatur: 0.5
# h das doch nicht so, daß er sich das doch das doch nicht mehr das wenige sich
# auch wieder, als er selbst nicht anderes er hinter dem mädezigen gedinken und sich die frau war es so sein setzten, in dem abends zu sein an der beinen könne, das da, gerald dann das einmal daran an der beiden könne er sich auch nichts anderen, das zu gleichzeitig das gedanken in der stadt, wenn er sich ebensüngemachte, die wohnung ein deshalb gebrüht. das genüger streifen, gewor
# ------ Temperatur: 1.0
# die wohnung ein deshalb gebrüht. das genüger streifen, geworden, wieder die stramm noch ein klavierten blickten könnete dieses
# gewohnten stand, praften sich jedesmal
# aus halb
# gerubt als. ohne dabei sie, zwei tricke, es schließt
# wir war ander wurden ziel anderen rauber. auskeindum tail, lassen herausvornen, in einem
# stadt als wie  der wohnungen, jo
# frisiertes wegen
# schalletwacksparien,
# eine gebspappt jeder stand, ein einziertstein so, was schneller.
# er war
# ------ Temperatur: 1.2
# pt jeder stand, ein einziertstein so, was schneller.
# er war nößgesbert war zuerst gepflegt kondet.
# die sich neusangem, ger disch zlickte. alsoooiogo, großengetaschlich.
# man gan zwöger als ein selzählicheierton, klumpl rekenstoffe, die seldevgrpptein rieben, eine vorwag. aber büsten,, mittreuitt, gewesen. sie.
# ei pragen friet
# auch groß stisl. e frags offen ir abzurücken, es kabisten manchmal bildehen etwackrig.
# jetzt mußtisch pall  gedankt, so ein genäust d
# epoch 11
# 1204/1204 [==============================] - 129s 107ms/step - loss: 1.2599
# --- Erzeuge Text mit dem Anfangswert: "t von dessen art, das besondere zu sehen, das anderen nicht "
# ------ Temperatur: 0.2
# t von dessen art, das besondere zu sehen, das anderen nicht angefallen war, die auf den beide beiden stelle den anderen standen aufgeschickt hatte, die sich das schon auf den auf den beine zu sehen, die sich das gehend herausgefür sich wieder aufgerichtet, die weißen blickte er sich das auf den keine gerald hinten dem beiden stelle auf den auf den kind aufgerichtet.
# die sich das gehend auf den beine zu beinen, die sich das gegangen war, die frauen, die sic
# ------ Temperatur: 0.5
# ne zu beinen, die sich das gegangen war, die frauen, die sich zu klar stand. gerald
# gehend herausgeschübsten schon war das gegenüber zu sehen, aber die sich eine kleinen finger auf den kindlose auf den ausgeschirben, ein einzigen geschichten. es gab aufgefallen und bilder, die aus den kar an den auf dem beiden halten in der lose nahl und die sich daraufgegen die auf den vierten dem beiden
# fleck den in gesehen, es war das kam in seinen schaufen klar war, di
# ------ Temperatur: 1.0
# n in gesehen, es war das kam in seinen schaufen klar war, die seinang empflar runter, sich die straße aufary
# grbübe. der mann nur halte nur wieder stehend, die sich hellig über die kaum nur. er konnte die dann schnell belnocst. inrenstille werden
# sasen. draufstungen noch gehtagt aufeinander zu regenheit greichen
# bein, die hielten blickt hineingeschlossen, genau von der enklärt,
# das zimmer unanküber hieltche zu für ihn
# bilder miß schien eine ständig hatte,
# ------ Temperatur: 1.2
# r hieltche zu für ihn
# bilder miß schien eine ständig hatte, seintg parkt den
# und tasches, bis
# seinen viertob wiederholen
# überhaufück hatte,
# k in enlklepres alten ton, geräuschen. es war nach ingestehen, gehörten, unhimklickt, nehztvin
# glatte sich aufschwieden. vie ein gelösten vor mieder
# dem zu irir, wenn denn em ganz stirben iherelhen bestimmt, sich danaüüaaß
# vor irner aschen
# wärn, bist dunsttrenden eingehenärlichewiltenn, rastbehen, deine loehel iaaferle
# epoch 12
# 1204/1204 [==============================] - 139s 115ms/step - loss: 1.2499
# --- Erzeuge Text mit dem Anfangswert: "ese ärsche an, nur weil sie einen gut finden. aber das muß
# d"
# ------ Temperatur: 0.2
# ese ärsche an, nur weil sie einen gut finden. aber das muß
# die sich auch wieder angesehen, die sich ausgeführen war, daß es sie war es nicht mehr so immer weggelegt hatte, das sie sich schon längst nicht mehr so war nicht anders gesehen war, daß er das eine straße vor ihm vor ihm an der straße aus dem bauch wegkinnte sich das sie sich an den kören schwer vor ihm wieder ein gesicht und ein wanden wollten stand vor ihm zu sein und sie war nicht das sie nicht
# ------ Temperatur: 0.5
# ollten stand vor ihm zu sein und sie war nicht das sie nicht schlecht gehen mit lose hinter den beinen sich zwischen den anderen körper und wieder eine gedanke, die vor ihm vor ihm wegzusehen konnte oder ein tag fertigen figur.
# das gleichen schwankst die bilder ein andere wieder auffallen hinter ihm die ecke vor ihm streichen bei den kreischen vorstellung, die wenige gegenüber und niedreer weiter, die niedrigen bildern genau von der straße bluten vor den k
# ------ Temperatur: 1.0
#  die niedrigen bildern genau von der straße bluten vor den kürze tag spant überward bei und weit leute weggeschmerken, wieder für sie bliebe
# zum ein kleidergheit. und sie war
# nicht schon übertuchte, oder sich ja in doch so zu aufherte, wirklich wieder verschwondent ist vor ein eigene bopfen spiegen vorwarden für angepatzten heite war verfürget zugutor, s abände, das fenster hatte, wirs man plötzlich ein gedeckt schon son, schlafen kurze, wärch neurasch von
# ------ Temperatur: 1.2
# ch ein gedeckt schon son, schlafen kurze, wärch neurasch von ihm war. alle kanlegne, so war eine erlauchte hilwinkeln der schattagjale groß ihn lerklos
# womdem host kam übem mittigzen unerkß von dem bildern, die ik, rockkrizilcd, nicht sing
# wild er
# her innen, verfried gelösten odeer hinhatkämmen. das war ungesucht wurde berongen unten risßchen verwiscrvor, ob die deuflre wegstarr, den lehrerte blvöt gedrückt, hier yot. lange nicht. sie zum reden ßechen zu s
# epoch 13
# 1204/1204 [==============================] - 131s 109ms/step - loss: 1.2445
# --- Erzeuge Text mit dem Anfangswert: "esend in ein und derselben wohnung im gleichen augenblick, u"
# ------ Temperatur: 0.2
# esend in ein und derselben wohnung im gleichen augenblick, und das gerald geworden. das stand nicht mehr und das geschenkt und das war es gerald hinter dem bett zu können, das sie sich eine stadt und diese blise bei mir das einmal das zusammen war, das sie das sein geschlecht, das eine stadt zu sehen war, das er sollte, daß er sich das zu sehen war, das sie nicht mehr so war es sie sich das das geschende, das gesehen war, das eine stand geschnitten, das si
# ------ Temperatur: 0.5
# schende, das gesehen war, das eine stand geschnitten, das sie sich dann und weiter zusammengezogen, in dem gedenkeln, das zeigte er sich das die bahnte ist die mädchen, wenn er sie dann, du das gedanke wend und mehr und so das bestimmten inten in dem moment als sein verkleicht, eine stadt da war, daß er das doch da war das durch das sein beschäftigen, das sich schon ließ nicht alles das nun zu aufgehend hatte er noch eigentlich sein, nicht war das hand, wi
# ------ Temperatur: 1.0
# gehend hatte er noch eigentlich sein, nicht war das hand, wie sie sich zu neben überpolien in ihnen
# weiter dagestöpp hüurte,
# da war mühe
# eingeschlessen, mehr mit plötzlich so weißes mit vorbeithelausd, wie nähe dazu, nach beschleckt, geraue richtig, ihm glaubte sich damit unterheift und es
# war in unten strampf,
# das lügte es wieder zu sammen tauch, sagten er hautn, ging, nichts mehr es errür ist einermal gleichzeit mit rainer körpe, die glatt sie sich mit h
# ------ Temperatur: 1.2
# nermal gleichzeit mit rainer körpe, die glatt sie sich mit heißlichen wöhn loch dazu, bleibend war
# er nichtsgemehrt
# strampft, aber doch, auf den
# bildschnitt warbos, kalteinis durchfinge dies, wieder ein anderes mittenal, der wohnung, holzäm
# alt spaften ständlung mal palon, döller.
# dechtigen
# schiefe gelegen, um, tropfen, iem die cemautl
# düssen
# paders, dtühe oder das,
# das denn
# freinöft,
# ohne weg was winter gezogen oder, alle
# mit bald jedesmelvoft marge. gert
# epoch 14
# 1204/1204 [==============================] - 147s 122ms/step - loss: 1.2355
# --- Erzeuge Text mit dem Anfangswert: "ner
# stelle, und jetzt blieben sie zusammen, die sonne schien"
# ------ Temperatur: 0.2
# ner
# stelle, und jetzt blieben sie zusammen, die sonne schien immer so einfach so immer nur noch einmal das gesehen, das gesehen, das war es ist das gesehen war, ein balkonen wohnung auf dem augenblickzerlicher wieder so bei ihnen auf dem abends gesehen, was war es genau auf dem abstellbar, wenn es gar nicht mehr vorstellte, sich darauf auf dem hochhausend vorher und das gesehen, wie er sie sich darauf das so genaugenammen, das sie sich dazustechte er sich
# ------ Temperatur: 0.5
# rauf das so genaugenammen, das sie sich dazustechte er sich auch nun war, so daß er einfach davor, so sie war, so daß er war, daß es immer sie sich eine geschicht hatte, obwohl es wichtig, das ist das gegenüber stecken blieben und das bildernen
# drehte er nicht. sie das so besagt aus der bücher. sie sich allein und auf den anderen stadtloß weg zu können, das sie sich das zugestellt, er hatte er, es nicht angefangen war. nein, in der augenblichen war und das
# ------ Temperatur: 1.0
#  nicht angefangen war. nein, in der augenblichen war und das wollte schon mit pabte, ein wohnumöfern
# und da leich mit starr, die schor tahres,
# wie sich so eingefallt wäre, das
# hütte, kurz geworfenzt dortheit. dann komr vorher überher, euklete sich vorstellte,
# unten umsteblich unterhafete und mehr auf dem hochhfalsetes, die bahnsteiß, überhaupt du vierf zischriftig herdunt gesehen hatte. ihr das
# anderes bilder des lustst auf dem platz,
# weilher das vorwagen,
# ------ Temperatur: 1.2
# deres bilder des lustst auf dem platz,
# weilher das vorwagen, da wargen
# doch nicht nurstügendei daliegen, nirgend
# wie sie, ich
# dachte daß das im eigen können, doch
# genausümer lag zusammen, fickig. gleichmäßlich, mädcherheiek
# komelne blüspbrachchchen und ghop zuvorgektrsehen wal. und wein nieen
# köpfständende stehalie frase dicht, dont gegen sie sagte nur en, daß es dagiävfagon, offen zu kämen, eine
# ausmache vorbettehn. erst sich biktallwegen, schten
# schliefi
# epoch 15
# 1204/1204 [==============================] - 143s 119ms/step - loss: 1.2238
# --- Erzeuge Text mit dem Anfangswert: "rauchte nun andere, nicht nur sie, auch andere kinder zum sp"
# ------ Temperatur: 0.2
# rauchte nun andere, nicht nur sie, auch andere kinder zum spröchen auf dem anderen ausgedreht in einer anderen war es das gelegenälieben vor ihm darauf der stadt wie das gelblichen war, das selbst du nicht mehr lag das gelblichen war schon gleich allein und dem aus der stadt und das war schon gab es das nicht mehr und das war das gelegenälieben mit der stadt gesehen war, das gesichter war das dach schon gar nicht angebracht, das war schon gab es doch nie d
# ------ Temperatur: 0.5
#  schon gar nicht angebracht, das war schon gab es doch nie darüber hingekommen war, das schlief, eine zigarette, nach der leeren in einem balkon geworden und so das zimmer
# hinter ihm aus der tür durch die aus dem andere und sie ihn dann sie im vorstellungen, das gelegenen briek, das war nichts mehr aus dem augenblick auf der stadt, wenn er dann nicht mehr angefallen war, dann an der anderen ansah, und das vor der stadt gedaupen hatte, das ganz seine straße
# ------ Temperatur: 1.0
#  und das vor der stadt gedaupen hatte, das ganz seine straße hinter, trafel darangehalten
# über hatte aus den tagen oder der nieder lang ist aus dem kleich daran tot übrängelle so, einen unsiftändlichkommen würde, eine betrobe
# als blund
# und sonhe rücksüch wegwenalis stuhlen, eine langsame
# vorher und sasger, die stellen tot hin kommend. sprichtt zu sah. die sorit, ich will hinfalk mein nemln. so, vor ihr gerald. londor, mehr, so das gnkam aus
# ihm, ihre ruhig
# ------ Temperatur: 1.2
# r ihr gerald. londor, mehr, so das gnkam aus
# ihm, ihre ruhig anblei, alligek, noch ach. eine lederjatu, klein schien wurde möge auf, das war zwischen
# ihnen noch unauffall zu änderne.
# völlig hoch. wederweru so noch mitulggoliein, lauf hatte er an ihnen, saß ließ und rücken, vorsieftnaue, in gestandenes war. empfrta, sovgrünlich rennwurr dann in lautlon für der
# glas, zmüischenhäulich
# mitsitätig anlaß, etwas
# weg mit hiellt, allesche ziimmer adschoch auch mal
# epoch 16
# 1204/1204 [==============================] - 146s 122ms/step - loss: 1.2205
# --- Erzeuge Text mit dem Anfangswert: "zuziehen
# versuchte, an sich heran, und den er kurz, da er si"
# ------ Temperatur: 0.2
# zuziehen
# versuchte, an sich heran, und den er kurz, da er sich das gesichter war es wieder das gesicht, das war es wieder so so ein geschlagen, das sich darauf das gesicht und das gesicht, das sie sich das darin und dann nicht das geschein. und das war das gesicht und sie wieder das alle vor ihm wieder ein geschnitten, die sich darauf das gestellt, das war es wieder ein geschmalen, die sich darauf war es wieder einmal darauf das gesicht, das war es war das
# ------ Temperatur: 0.5
#  war es wieder einmal darauf das gesicht, das war es war das war sie das ein finger sich hinten der sich ausgeschmutzte gehen. es war auf dem ausgestellt, das war nicht beraunen, die sie sich nicht mehr weggehen konnte
# er ein auf der stadt, ein schiebigen lichte sich wieder einmal von ihr in der balkon worden standen, wie diese eine geschnitten, der sich darauf, der er wieder einmal immer das gedanke, die beiden wohnung,
# das war es schon war ein aufgestell
# ------ Temperatur: 1.0
# nke, die beiden wohnung,
# das war es schon war ein aufgestellt, worad noch noch einmal und neben
# einem ammelomen fort wollte es ihm
# danach hatte, dieselben köspen das sah er einsette klargar
# plastlutte so eine grünen frau äußel an und
# beruhigtsammen ist noch darin, im vornachlastel vorstellung hatte, anstuhl, weglich immer doch gut,
# ein kälte, dieses oder nähe er schon durch eine aut, meit diese crstgaus unsichtbar
# so, ihm mehr durchfaugen und dann noch ein
# ------ Temperatur: 1.2
# stgaus unsichtbar
# so, ihm mehr durchfaugen und dann noch ein mit vor einer mompbt wo. das er noch einmal ein soijauhemiof, war. nichts, und sie war in nicht im bild, bigen, kööfe in der frau oder dazu rückripig,
# daß auchung vollio, die beiden möpperes zurüngen.
# schrb gerald vom ihr karogand
# es oberstraße an, daß mansch, und nicht nur umaugen blieb, ein vor dann nur nur zu oder viet, ode, ob dessen, hamte, einen, art, war es da hinrichengebleiben. war, ich
# epoch 17
# 1204/1204 [==============================] - 112s 93ms/step - loss: 1.2161
# --- Erzeuge Text mit dem Anfangswert: "räusche von draußen, den verkehr, die betriebsamkeit, gedämp"
# ------ Temperatur: 0.2
# räusche von draußen, den verkehr, die betriebsamkeit, gedämpften bewegungen geschwinden, die so schwere beinen darin, wenn er sich ein schwitzenden bewegung war das gesicht, das er sich das gestellt war, das er sich das so war, das er sie sich das gesicht, das sie sich das gestrichen war, daß er sich das ein auf dem schritte war, das er sich selbst das gesicht, das er sich selbst das gesicht, das er sich das ein stand schon gleichen bein auf dem er das ges
# ------ Temperatur: 0.5
# er sich das ein stand schon gleichen bein auf dem er das gesicht, ein schultern und der straßen auf dem ausgestellen war, daß er hatte er sonst gedanke, ich meinen, sie schon lange war und so waren das eine straße, die seinen zugenau wieder so darin, das darin, als seit ihm es schien er einmal das in dem rotlich gegenüber bein, alles war er zu der wohnung, sie wollte er zu zimmer weggeblieben hatte, wie er sich ein flimmern und dann, er wollte er sich ansc
# ------ Temperatur: 1.0
# e, wie er sich ein flimmern und dann, er wollte er sich anschnitte, frisch aufmaschallenden bekomhen.
# leer
# seit schaß wiederhalt sehr besch. ihr dann wieder wieder gesagt hatte, dabei greißen um sich
# gleich dazeir auf deine bar, wie erledigt,
# sonst, spät nach unten, wollchen pomina an während den bödaum, dreck unterdrdichungen er bei dem beinende händlich, weiter, dem wohnn sie plötzlich das zimmer
# weg, nackte bestimmt geworden. vom anderen schwach augenge
# ------ Temperatur: 1.2
# r
# weg, nackte bestimmt geworden. vom anderen schwach augengegangt. ohre mit
# dir sor und wag. die wadersit ohnesernhib, weg in dem zuwom zu sich heran, man redberund
# erschenhe, gleichfuultres gabii ne, um umrippte, so daß ihm a, um sich erklärt,
# konnte sie hoch,remwngen,
# gar nun wennchen raucher mußter und zu sehen,
# es machei zum
# zimmerten umzuf
# ußen. die eieme ge
# noch einp so wieder,
# kam enggeschnimmerschafft. jenaliecehsten,
# schallplatten, da wirster ,
# en
# epoch 18
# 1204/1204 [==============================] - 117s 97ms/step - loss: 1.2124
# --- Erzeuge Text mit dem Anfangswert: "en rücken griffen, ihre kleine schlängelnde
# bewegung unter i"
# ------ Temperatur: 0.2
# en rücken griffen, ihre kleine schlängelnde
# bewegung unter ihm darauf auf dem abend, das sie sich das bei ihnen auf dem ausgehen konnte, daß er sich ausgefahren war auf dem abends selber aus der stadt gesehen waren, daß er sich darauf das geht immer so eine augenblick
# schon auf der stelle das ausgebreitet hatten, das sie sich ausgebreitet war das genauern und schon gar nicht mehr ausgebreitet hatte, das sie sich darauf das geht auch nicht mehr schon gleich
# ------ Temperatur: 0.5
# e, das sie sich darauf das geht auch nicht mehr schon gleichhändiges kank und sehr schon ein kleine stand weggehosen, nicht mehr war es das bei ihm auch einfach heraus vorbeigeine bewegungen, der rainer darauf wieder aufgelöst hatte, der er wie immer bei der stelle tran eine frau erstarten. das war es schon länger
# gehen das gesprott war und das zimmer war es sich hielte er gerald das nächsten gedachte herausgeschlecht und erledigt, merkte, wie er ein gedan
# ------ Temperatur: 1.0
# chte herausgeschlecht und erledigt, merkte, wie er ein gedannenn darauf eine bütten sich zurückgekommen. rainer, das betau zu eine ausfallung
# noch nicht mwetzt
# er ihn dort bis redes sein sollten,
# soganz waren da in einem wurdnlich aufgereeten und selbst prägfen, manchmache zwischen verhörte, mit sich hinüber unten körperlige gebichelte, weiß nach stellgelteschen wurde hand. verum wegen wie im angepaßter zu ändeune, wenn er doch weiter ein blick, war es aus
# ------ Temperatur: 1.2
# paßter zu ändeune, wenn er doch weiter ein blick, war es aus schier äuferres still stand, sie, jeder. friemte war, oöker raum, wegöpfnge, , war die stikier auf die weise voll, daß er wenig genau angehängen
# wart. stiezte er sich geringung lag vorihten wasser, alles mit, was bahna drüh lag flüst, ja, etwas durch b älter ohne bauch.
# eine nacktüren, anmasch der morgen
# überollen, ein sacke, weiß nicht, imal, hatte ein fetet. nademsap, wiederung aufgelogen, obwo
# epoch 19
# 1204/1204 [==============================] - 109s 90ms/step - loss: 1.2057
# --- Erzeuge Text mit dem Anfangswert: " an der küste. ja, an der küste. er war noch nie vorher dage"
# ------ Temperatur: 0.2
#  an der küste. ja, an der küste. er war noch nie vorher dagestellte sich von ihm aus, die sie sich auch wieder einmal das sie sich dann auch schließend sie sich das schnell und er sich auch wieder ausgebreitet hatte, daß es sie sich das sich darauf der sie nicht mehr sein gerald in der sie sich ausgebreitet war
# --------------------------------------------------------
# KeyboardInterrupt      Traceback (most recent call last)
# <ipython-input-7-5e1a7073d040> in <module>
#      27                 sampled[0, t, char_indices[char]] = 1.
#      28
# ---> 29             preds = model.predict(sampled, verbose=0)[0]
#      30             next_index = sample(preds, temperature)
#      31             # sampling des nächsten Zeichens
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1718                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1719
# -> 1720       data_handler = data_adapter.get_data_handler(
#    1721           x=x,
#    1722           batch_size=batch_size,
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     318       return flat_dataset
#     319
# --> 320     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     321
#     322     dataset = self.slice_inputs(indices_dataset, inputs)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func)
#    1901       Dataset: A `Dataset`.
#    1902     """
# -> 1903     return FlatMapDataset(self, map_func)
#    1904
#    1905   def interleave(self,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func)
#    5060     """See `Dataset.flat_map()` for details."""
#    5061     self._input_dataset = input_dataset
# -> 5062     self._map_func = StructuredFunctionWrapper(
#    5063         map_func, self._transformation_name(), dataset=input_dataset)
#    5064     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4216         fn_factory = trace_tf_function(defun_kwargs)
#    4217
# -> 4218     self._function = fn_factory()
#    4219     # There is no graph to add in eager mode.
#    4220     add_to_graph &= not context.executing_eagerly()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3148          or `tf.Tensor` or `tf.TensorSpec`.
#    3149     """
# -> 3150     graph_function = self._get_concrete_function_garbage_collected(
#    3151         *args, **kwargs)
#    3152     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3114       args, kwargs = None, None
#    3115     with self._lock:
# -> 3116       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3117       seen_names = set()
#    3118       captured = object_identity.ObjectIdentitySet(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapped_fn(*args)
#    4193           attributes=defun_kwargs)
#    4194       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4195         ret = wrapper_helper(*args)
#    4196         ret = structure.to_tensor_list(self._output_structure, ret)
#    4197         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_helper(*args)
#    4123       if not _should_unpack(nested_args):
#    4124         nested_args = (nested_args,)
# -> 4125       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4126       if _should_pack(ret):
#    4127         ret = tuple(ret)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py in slice_batch_indices(indices)
#     307           first_k_indices, [num_full_batches, batch_size])
#     308
# --> 309       flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     310       if self._partial_batch_size:
#     311         index_remainder = tf.data.Dataset.from_tensors(tf.slice(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors)
#     683       Dataset: A `Dataset`.
#     684     """
# --> 685     return TensorSliceDataset(tensors)
#     686
#     687   class _GeneratorState(object):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element)
#    3854           tensor_shape.dimension_value(t.get_shape()[0])))
#    3855
# -> 3856     variant_tensor = gen_dataset_ops.tensor_slice_dataset(
#    3857         self._tensors,
#    3858         output_shapes=structure.get_flat_tensor_shapes(self._structure))
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py in tensor_slice_dataset(components, output_shapes, name)
#    7125         "'tensor_slice_dataset' Op, not %r." % output_shapes)
#    7126   output_shapes = [_execute.make_shape(_s, "output_shapes") for _s in output_shapes]
# -> 7127   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7128         "TensorSliceDataset", components=components,
#    7129                               output_shapes=output_shapes, name=name)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     746       # Add Op to graph
#     747       # pylint: disable=protected-access
# --> 748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
#     750                                  attrs=attr_protos, op_def=op_def)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     597       inp = self.capture(inp)
#     598       captured_inputs.append(inp)
# --> 599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     601         compute_device)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3559     # Session.run call cannot occur between creating and mutating the op.
#    3560     with self._mutation_lock():
# -> 3561       ret = Operation(
#    3562           node_def,
#    3563           self,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2039       if op_def is None:
#    2040         op_def = self._graph._get_op_def(node_def.op)
# -> 2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1874     # TODO(skyewm): this creates and deletes a new TF_Status for every attr.
#    1875     # It might be worth creating a convenient way to re-use the same status.
# -> 1876     pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1877                                            serialized)
#    1878
#
# KeyboardInterrupt:
